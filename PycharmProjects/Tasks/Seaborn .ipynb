# %% [markdown]
# # seaborn
# #### seaborn is used as data visualization and also gives as hight level interface  for creative information

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
x = pd.pivot_table(df,index='Survived',columns='Sex',values='Age')

# %%
x
# Out:
# Sex          female       male
# Survived
# 0         19.790123  24.321581
# 1         24.390558  23.272202

# %%
sns.heatmap(x,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
cor=df.corr()

# %%
cor
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.038125 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481  0.010539 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.361353  0.083081  0.018443
# Age             0.038125  0.010539 -0.361353  1.000000 -0.184664 -0.048786
# SibSp          -0.057527 -0.035322  0.083081 -0.184664  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.048786  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.135516  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.135516
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(cor,annot=True,cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
pt = pd.read_csv('sales.csv')

# %%
pt
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
pt['Year']=pd.DatetimeIndex(pt['Ship_Date']).year

# %%
pt['Month']=pd.DatetimeIndex(pt['Ship_Date']).month

# %%
pt
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# total profit,year,month create heatmap for this

# %%
pt = pd.pivot_table(pt,index='Total_Profit',columns='Year',values='Month')

# %%
pt
# Out:
# Year          2010  2011  2012  2013  2014  2015  2016  2017
# Total_Profit
# 1258.02        NaN   NaN   5.0   NaN   NaN   NaN   NaN   NaN
# 1621.93        NaN   NaN   NaN   NaN   NaN   9.0   NaN   NaN
# 5270.67        NaN   NaN   NaN   NaN  10.0   NaN   NaN   NaN
# 6841.38        NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 7828.12        NaN   7.0   NaN   NaN   NaN   NaN   NaN   NaN
# ...            ...   ...   ...   ...   ...   ...   ...   ...
# 1487261.02     NaN   NaN   NaN   NaN   NaN   NaN   NaN   2.0
# 1505888.07     NaN   NaN  10.0   NaN   NaN   NaN   NaN   NaN
# 1541705.29     NaN   NaN   NaN   NaN   NaN   NaN  12.0   NaN
# 1678540.98     NaN   NaN   NaN   8.0   NaN   NaN   NaN   NaN
# 1719922.04     NaN   NaN   NaN   8.0   NaN   NaN   NaN   NaN
#
# [100 rows x 8 columns]

# %%
sns.heatmap(pt,annot=True,cmap='Reds')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total_Profit'>

# %%
correlation=pt.corr()

# %%
correlation
# Out:
# Year  2010  2011  2012  2013  2014  2015  2016  2017
# Year
# 2010   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2011   NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2012   NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN
# 2013   NaN   NaN   NaN   1.0   NaN   NaN   NaN   NaN
# 2014   NaN   NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 2015   NaN   NaN   NaN   NaN   NaN   1.0   NaN   NaN
# 2016   NaN   NaN   NaN   NaN   NaN   NaN   1.0   NaN
# 2017   NaN   NaN   NaN   NaN   NaN   NaN   NaN   1.0

# %%
sns.heatmap(correlation,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Year'>
